# %% [markdown]
# # Cargo datos

# %%
import json
import requests
import pandas as pd
from pandas import json_normalize
import os
from dotenv import load_dotenv
import datetime
import re

load_dotenv()
# Out:
# True

# %%
from src import cleaning_functions as cf

# %%
df = cf.leer_datos()
df = df[df.Expediente.isna()       == False]
df = df[df.Coordenada_UTM_Y.isna() == False]

cf.traducir_colores(df)
cf.traducir_dias_semana(df)
cf.traducir_meses(df)
cf.traducir_tipo_vehiculo(df)
cf.limpiar_Carnets(df)
cf.limpiar_antiguedad(df)
cf.limpiar_distrito(df)
cf.traducir_causa(df)
cf.calcular_turno(df)

df.drop(['Codigo_Postal', 'Tipo_dia', 'Longitud', 'Latitud'], axis=1, inplace=True)
print('Se han quitado columnas que no se usarán posteriormente')
df.drop_duplicates()
print('Se han quitado filas duplicadas')

df.Modelo.fillna('Desconocido',inplace = True)
df.Modelo.replace({'Desconegut':'Desconocido'})
df.Marca.fillna('Desconocido',inplace=True)
df.Marca.replace({'Desconegut':'Desconocido'})
df.Calle.fillna('Desconocido',inplace=True)
print('Se han limpiado los Nan y se han traducido los desconocidos a castellaño ')
# Out:
# Leemos data/accidents/2010-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2011-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2012-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2013-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2014-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2015-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2016-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2017-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2018-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2019-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Leemos data/accidents/2020-accidents-vehicles-bcn.csv y adjuntamos en el dataframe
# Se han traducido los colores a castellaño
# Se han traducido los dias de la semana a castellaño
# Se han traducido los meses a castellaño
# Se han clasificado los tipos de vehículos en castellaño
# Se han clasificado los carnets
# Se han limpiado las antiguedades incoherentes
# Se han corregido y unificado los nombres de los distritos
# Se han traducido las causas del accidente a castellaño
# Se han calculado los turnos según la hora
# Se han quitado columnas que no se usarán posteriormente
# Se han limpiado los Nan y se han traducido los desconocidos a castellaño

# %%
df[df.duplicated()]
# Out:
#          Expediente Distrito_codigo        Distrito Barrio_codigo  \
# 100698  2015S002128               7  Horta-Guinardó            34
# 104404  2015S005539               2        Eixample             7
# 104420  2015S007684               2        Eixample             7
#
#                         Barrio Calle_codigo                      Calle  \
# 100698                Can Baró       365702  Mare de Déu de Montserrat
# 104404  la Dreta de l'Eixample       148307                     Gràcia
# 104420  la Dreta de l'Eixample       148307                     Gràcia
#
#        Dia_semana Dia_semana_corto   Año  ...      Modelo       Marca  \
# 100698    Viernes                V  2015  ...       SH 50       HONDA
# 104404    Viernes                V  2015  ...  Desconegut      BICING
# 104420     Martes                M  2015  ...  Desconegut  Desconegut
#
#               Color      Carnet   Antiguedad Coordenada_UTM_Y  \
# 100698  Desconocido  Desconegut  Desconocido       4585349,36
# 104404  Desconocido  Desconegut  Desconocido       4583088,81
# 104420  Desconocido  Desconegut  Desconocido       4582566,28
#
#        Coordenada_UTM_X  Turno Tipo_veh_grup Carnet_reducido
# 100698        430286,94  Tarde    Ciclomotor     Desconocido
# 104404        430002,08  Tarde     Bicicleta     Desconocido
# 104420        430479,23  Tarde     Bicicleta     Desconocido
#
# [3 rows x 26 columns]

# %%
df.shape
# Out:
# (197268, 26)

# %%
df.drop_duplicates()
# Out:
#              Expediente Distrito_codigo        Distrito Barrio_codigo  \
# 0           2010S002961               7  Horta-Guinardó            34
# 1           2010S003114               8      Nou Barris            53
# 2           2010S001244               3  Sants-Montjuïc            11
# 3           2010S001244               3  Sants-Montjuïc            11
# 4           2010S001421               2        Eixample             5
# ...                 ...             ...             ...           ...
# 197283  2020S006276                   1    Ciutat Vella             2
# 197284  2020S006276                   1    Ciutat Vella             2
# 197285  2020S006277                   2        Eixample             9
# 197286  2020S006278                   8      Nou Barris            44
# 197287  2020S006278                   8      Nou Barris            44
#
#                                 Barrio Calle_codigo                 Calle  \
# 0                             Can Bar¢       170601  Jos Mill n Gonz lez
# 1                     la Trinitat Nova         4409            Aiguablava
# 2                         el Poble Sec       701266   Litoral (Llobregat)
# 3                         el Poble Sec       701266   Litoral (Llobregat)
# 4                        el Fort Pienc       325005               Sic¡lia
# ...                                ...          ...                   ...
# 197283                 el Barri GÃ²tic       701266   Litoral (Llobregat)
# 197284                 el Barri GÃ²tic       701266   Litoral (Llobregat)
# 197285  la Nova Esquerra de l'Eixample        18505                AragÃ³
# 197286   Vilapicina i la Torre Llobeta        45701                Quinze
# 197287   Vilapicina i la Torre Llobeta        45701                Quinze
#
#        Dia_semana Dia_semana_corto   Año  ...            Modelo       Marca  \
# 0         Viernes                V  2010  ...              GOLF  VOLKSWAGEN
# 1         Viernes                V  2010  ...                YR      YAMAHA
# 2         Viernes                V  2010  ...          BERLINGO     CITROEN
# 3         Viernes                V  2010  ...            TOLEDO        SEAT
# 4         Viernes                V  2010  ...           TRANSIT        FORD
# ...           ...              ...   ...  ...               ...         ...
# 197283     Jueves                J  2020  ...  AGILITY CITY 125       KYMCO
# 197284     Jueves                J  2020  ...        Desconegut  Desconegut
# 197285     Jueves                J  2020  ...            SH 150       HONDA
# 197286     Martes                M  2020  ...              CLIO     RENAULT
# 197287     Martes                M  2020  ...             RAPID       SKODA
#
#                  Color      Carnet   Antiguedad Coordenada_UTM_Y  \
# 0          Desconocido           B            3       4585536,52
# 1                Negro          AM            1       4589093,65
# 2               Blanco           B            9        4578885,9
# 3          Desconocido         BTP           16        4578885,9
# 4               Blanco           B            5       4583562,68
# ...                ...         ...          ...              ...
# 197283     Desconocido           B           16       4581077.37
# 197284           Negro  Desconegut  Desconocido       4581077.37
# 197285            Rojo           A           25       4581954.15
# 197286          Blanco  Desconegut  Desconocido       4586654.09
# 197287  Negro/Amarillo  Desconegut  Desconocido       4586654.09
#
#        Coordenada_UTM_X   Turno Tipo_veh_grup Carnet_reducido
# 0             429863,89   Noche       Turismo               B
# 1             431789,16   Tarde    Ciclomotor               A
# 2             429949,38   Tarde     Furgoneta               B
# 3             429949,38   Tarde       Turismo               B
# 4             431291,81   Tarde     Furgoneta               B
# ...                 ...     ...           ...             ...
# 197283         431410.4   Tarde   Motocicleta               B
# 197284         431410.4   Tarde         Otros     Desconocido
# 197285        429362.84   Tarde   Motocicleta               A
# 197286        431221.22  Mañana       Turismo     Desconocido
# 197287        431221.22  Mañana       Turismo     Desconocido
#
# [197265 rows x 26 columns]

# %%
df.to_csv('output/accidents_Bcn_limpio.csv' , index=False , encoding='latin-1')
